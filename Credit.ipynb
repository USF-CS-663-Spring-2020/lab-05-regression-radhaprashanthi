# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Read the data
df = pd.read_csv('Credit.csv')
df
# Out:
#      Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0             1   14.891   3606     283      2   34         11    Male
# 1             2  106.025   6645     483      3   82         15  Female
# 2             3  104.593   7075     514      4   71         11    Male
# 3             4  148.924   9504     681      3   36         11  Female
# 4             5   55.882   4897     357      2   68         16    Male
# ..          ...      ...    ...     ...    ...  ...        ...     ...
# 395         396   12.096   4100     307      3   32         13    Male
# 396         397   13.364   3838     296      5   65         17    Male
# 397         398   57.872   4171     321      5   67         12  Female
# 398         399   37.728   2525     192      1   44         13    Male
# 399         400   18.701   5524     415      5   64          7  Female
#
#     Student Married         Ethnicity  Balance
# 0        No     Yes         Caucasian      333
# ...

# %% [markdown]
# ### Income vs Limit

# %%
sns.scatterplot(x='Income', y='Limit', data=df)

# %%
sns.residplot('Income', 'Limit', data=df)

#random distribution around the regression line. So good

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(df[['Limit']], df[['Income']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_
# Out:
# array([[0.01209453]])

# %%
lin_reg.intercept_
# Out:
# array([-12.05596648])

# %% [markdown]
# #### Income can be a predictor for Limit using SLR for the line y = 0.012 * x - 12.056

# %%
from sklearn.model_selection import train_test_split

X = df['Income'].values.reshape(-1,1)
y = df['Limit'].values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_
# Out:
# array([[52.3389678]])

# %%
lin_reg.intercept_
# Out:
# array([2355.70503219])

# %%
y_pred = lin_reg.predict(X_test)

# %%
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %% [markdown]
# The above graph shows SLR can be used to predict Limit based on Income

# %% [markdown]
# ### Rating vs Limit

# %%
sns.scatterplot(x='Rating', y='Limit', data=df)

# %%
sns.residplot('Rating', 'Limit', data=df)

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(df[['Limit']], df[['Rating']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_
# Out:
# array([[0.06682326]])

# %%
lin_reg.intercept_
# Out:
# array([38.49178871])

# %% [markdown]
# #### Rating can be a good predictor for Limit using SLR for the line y = 0.1 * x + 38.5

# %%
from sklearn.model_selection import train_test_split

X = df['Rating'].values.reshape(-1,1)
y = df['Limit'].values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_
# Out:
# array([[14.90568462]])

# %%
lin_reg.intercept_
# Out:
# array([-559.11966558])

# %%
y_pred = lin_reg.predict(X_test)

# %%
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %% [markdown]
# The above graph shows SLR can be used to predict Limit based on Rating

# %% [markdown]
# ### Cards vs Limit

# %%
sns.scatterplot(x='Cards', y='Limit', data=df)

# %%
sns.residplot('Cards', 'Limit', data=df)

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(df[['Limit']], df[['Cards']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_
# Out:
# array([[6.07831934e-06]])

# %%
lin_reg.intercept_
# Out:
# array([2.92871551])

# %% [markdown]
# #### Cards cannot be a good predictor for Limit using SLR for the line y = (6.07831934e-06) * x + 2.93

# %%
from sklearn.model_selection import train_test_split

X = df['Cards'].values.reshape(-1,1)
y = df['Limit'].values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_
# Out:
# array([[-7.91376116]])

# %%
lin_reg.intercept_
# Out:
# array([4741.38691995])

# %%
y_pred = lin_reg.predict(X_test)

# %%
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %% [markdown]
# The above graph shows SLR cannot be used to predict Limit based on Cards

# %% [markdown]
# ### Age vs Limit

# %%
sns.scatterplot(x='Age', y='Limit', data=df)

# %%
sns.residplot('Age', 'Limit', data=df)

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(df[['Limit']], df[['Age']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_
# Out:
# array([[0.00075396]])

# %%
lin_reg.intercept_
# Out:
# array([52.09703154])

# %% [markdown]
# #### Age may not be a good predictor for Limit using SLR for the line y = 0.00075 * x + 52.097

# %%
from sklearn.model_selection import train_test_split

X = df['Age'].values.reshape(-1,1)
y = df['Limit'].values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_
# Out:
# array([[16.33252741]])

# %%
lin_reg.intercept_
# Out:
# array([3807.6886602])

# %%
y_pred = lin_reg.predict(X_test)

# %%
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %% [markdown]
# The above graph shows SLR can be used to predict Limit based on Rating

# %% [markdown]
# ### Education vs Limit

# %%
sns.scatterplot(x='Education', y='Limit', data=df)

# %%
sns.residplot('Education', 'Limit', data=df)

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(df[['Limit']], df[['Education']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_
# Out:
# array([[-3.18837514e-05]])

# %%
lin_reg.intercept_
# Out:
# array([13.60098869])

# %% [markdown]
# #### Education cannot be a good predictor for Limit using SLR for the line y = (-3.18837514e-05) * x + 13.6

# %%
from sklearn.model_selection import train_test_split

X = df['Education'].values.reshape(-1,1)
y = df['Limit'].values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_
# Out:
# array([[-4.38371912]])

# %%
lin_reg.intercept_
# Out:
# array([4777.06745378])

# %%
y_pred = lin_reg.predict(X_test)

# %%
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %% [markdown]
# The above graph shows SLR can not be used to predict Limit using Education
