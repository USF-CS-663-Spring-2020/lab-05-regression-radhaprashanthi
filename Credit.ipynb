# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Read the data
df = pd.read_csv('Credit.csv')
df
# Out:
#      Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0             1   14.891   3606     283      2   34         11    Male
# 1             2  106.025   6645     483      3   82         15  Female
# 2             3  104.593   7075     514      4   71         11    Male
# 3             4  148.924   9504     681      3   36         11  Female
# 4             5   55.882   4897     357      2   68         16    Male
# ..          ...      ...    ...     ...    ...  ...        ...     ...
# 395         396   12.096   4100     307      3   32         13    Male
# 396         397   13.364   3838     296      5   65         17    Male
# 397         398   57.872   4171     321      5   67         12  Female
# 398         399   37.728   2525     192      1   44         13    Male
# 399         400   18.701   5524     415      5   64          7  Female
#
#     Student Married         Ethnicity  Balance
# 0        No     Yes         Caucasian      333
# ...

# %% [markdown]
# ### Income vs Limit

# %%
sns.scatterplot(x='Income', y='Limit', data=df)

# %%
ax = sns.residplot('Income', 'Limit', data=df)
ax.set(xlabel='Income', ylabel='Residuals')
#random distribution around the regression line. So good
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Income')]

# %% [markdown]
# #### From the above residual graph we can see that the variance remains contant overall. So, Income can be a good predictor for Limit using SLR

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(df[['Income']], df[['Limit']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_, lin_reg.intercept_
# Out:
# (array([[51.8750206]]), array([2389.86940892]))

# %%
from sklearn.model_selection import train_test_split

X = df['Income'].values.reshape(-1,1)
y = df['Limit'].values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_
# Out:
# array([[52.3389678]])

# %%
lin_reg.intercept_
# Out:
# array([2355.70503219])

# %%
y_pred = lin_reg.predict(X_test)

# %%
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %% [markdown]
# #### The above graph shows Income can be a good predictor for Limit using SLR, as we can see uniform variance throught the regression line

# %% [markdown]
# ### Rating vs Limit

# %%
sns.scatterplot(x='Rating', y='Limit', data=df)

# %%
ax = sns.residplot('Rating', 'Limit', data=df)
ax.set(xlabel='Rating', ylabel='Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Rating')]

# %% [markdown]
# #### The above residual graph shows that the variance is almost constant. So, Rating can be a good predictor for Limit using SLR

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(df[['Rating']], df[['Limit']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_, lin_reg.intercept_
# Out:
# (array([[14.87160712]]), array([-542.92822999]))

# %%
from sklearn.model_selection import train_test_split

X = df['Rating'].values.reshape(-1,1)
y = df['Limit'].values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_
# Out:
# array([[14.90568462]])

# %%
lin_reg.intercept_
# Out:
# array([-559.11966558])

# %%
y_pred = lin_reg.predict(X_test)

# %%
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %% [markdown]
# #### The above graph shows Rating can be a good predictor for Limit using SLR, as we can see uniform variance throught the regression line

# %% [markdown]
# ### Cards vs Limit

# %%
sns.scatterplot(x='Cards', y='Limit', data=df)

# %%
ax = sns.residplot('Cards', 'Limit', data=df)
ax.set(xlabel='Cards', ylabel='Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Cards')]

# %% [markdown]
# #### The above residual graph shows that variance is not constant. So, Cards may not be a good predictor for Limit using SLR

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(df[['Cards']], df[['Limit']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_, lin_reg.intercept_
# Out:
# (array([[17.22189457]]), array([4684.66624682]))

# %%
from sklearn.model_selection import train_test_split

X = df['Cards'].values.reshape(-1,1)
y = df['Limit'].values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_
# Out:
# array([[-7.91376116]])

# %%
lin_reg.intercept_
# Out:
# array([4741.38691995])

# %%
y_pred = lin_reg.predict(X_test)

# %%
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %% [markdown]
# #### The above graph shows Cards may not be a good predictor for Limit using SLR as the we can see variance is not uniform throught the regression line

# %% [markdown]
# ### Age vs Limit

# %%
sns.scatterplot(x='Age', y='Limit', data=df)

# %%
ax = sns.residplot('Age', 'Limit', data=df)
ax.set(xlabel='Age', ylabel='Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Age')]

# %% [markdown]
# #### The above residual graph shows that the variance is almost constant. So, Age can be a good predictor for Limit using SLR

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(df[['Age']], df[['Limit']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_, lin_reg.intercept_
# Out:
# (array([[13.49982568]]), array([3984.09845403]))

# %%
from sklearn.model_selection import train_test_split

X = df['Age'].values.reshape(-1,1)
y = df['Limit'].values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_, lin_reg.intercept_
# Out:
# (array([[16.33252741]]), array([3807.6886602]))

# %%
y_pred = lin_reg.predict(X_test)

# %%
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %% [markdown]
# #### The above graph shows Age can be a good predictor for Limit using SLR, as we can see variance is almost uniform throught the regression line

# %% [markdown]
# ### Education vs Limit

# %%
sns.scatterplot(x='Education', y='Limit', data=df)

# %%
ax = sns.residplot('Education', 'Limit', data=df)
ax.set(xlabel='Education', ylabel='Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Education')]

# %% [markdown]
# #### The above residual graph shows that the variance is not constant. So, Education may not be a good predictor for Limit using SLR

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(df[['Education']], df[['Limit']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_, lin_reg.intercept_
# Out:
# (array([[-17.39235309]]), array([4969.52714909]))

# %%
from sklearn.model_selection import train_test_split

X = df['Education'].values.reshape(-1,1)
y = df['Limit'].values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_, lin_reg.intercept_
# Out:
# (array([[-4.38371912]]), array([4777.06745378]))

# %%
y_pred = lin_reg.predict(X_test)

# %%
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %% [markdown]
# #### The above graph shows Education may not be a good predictor for Limit using SLR, as we can see variance is not uniform throught the regression line

# %% [markdown]
# ### Conclusion
# From the above analysis we can say that Income, Rating and Age are good predictors for Limit as the variance is not changing much in their residual graphs compared to Cards and Education.
